# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# %%
finals_fbref = [
    {"id": "8f71b212", "title": "Real-Madrid-Liverpool-May-26-2018-Champions-League"},
    {"id": "96de6624", "title": "Tottenham-Hotspur-Liverpool-June-1-2019-Champions-League"},
    {"id": "f3c64f12", "title": "Paris-Saint-Germain-Bayern-Munich-August-23-2020-Champions-League"},
    {"id": "74010cc4", "title": "Manchester-City-Chelsea-May-29-2021-Champions-League"},
    {"id": "e81453d3", "title": "Liverpool-Real-Madrid-May-28-2022-Champions-League"},
    {"id": "32081d2b", "title": "Manchester-City-Internazionale-June-10-2023-Champions-League"},
    {"id": "92843563", "title": "Dortmund-Real-Madrid-June-1-2024-Champions-League"},
    {"id": "5185c7d5", "title": "Paris-Saint-Germain-Internazionale-May-31-2025-Champions-League"},

    {"id": "799cf803", "title": "Nigeria-Cote-dIvoire-February-11-2024-Africa-Cup-of-Nations"},
    {"id": "2ca5b81c", "title": "Senegal-Egypt-February-6-2022-Africa-Cup-of-Nations"},
    {"id": "deaede2a", "title": "Senegal-Algeria-July-19-2019-Africa-Cup-of-Nations"},

    {"id": "39b037a9", "title": "Argentina-Colombia-July-14-2024-Copa-America"},
    {"id": "1309eaf0", "title": "Argentina-Brazil-July-10-2021-Copa-America"},
    {"id": "33ec99f1", "title": "Brazil-Peru-July-7-2019-Copa-America"},

    {"id": "e307ecc0", "title": "Spain-England-July-14-2024-UEFA-Euro-2024"},
    {"id": "56228480", "title": "Italy-England-July-11-2021-UEFA-Euro-2020"},

    {"id": "dc399ca6", "title": "Portugal-Spain-June-8-2025-UEFA-Nations-League"},
    {"id": "c7cc0ff5", "title": "Croatia-Spain-June-18-2023-UEFA-Nations-League"},
    {"id": "82df6636", "title": "Spain-France-October-10-2021-UEFA-Nations-League"},
    {"id": "322368d7", "title": "Portugal-Netherlands-June-9-2019-UEFA-Nations-League"},

    {"id": "6d9230c5", "title": "Jordan-Qatar-February-10-2024-Asian-Cup"},
    {"id": "a7940000", "title": "Japan-Qatar-February-1-2019-Asian-Cup"},

    {"id": "ed5dc867", "title": "Chelsea-Paris-Saint-Germain-July-13-2025-FIFA-Club-World-Cup"},
    {"id": "790561d3", "title": "Manchester-City-Fluminense-December-22-2023-FIFA-Club-World-Cup"},
    {"id": "b96f7ccb", "title": "Real-Madrid-Al-Hilal-February-11-2023-FIFA-Club-World-Cup"},
    {"id": "1d346ab2", "title": "Chelsea-Palmeiras-February-12-2022-FIFA-Club-World-Cup"},
    {"id": "abd98ebb", "title": "Bayern-Munich-UANL-February-11-2021-FIFA-Club-World-Cup"},
    {"id": "cb8fcb6b", "title": "Liverpool-Flamengo-December-21-2019-FIFA-Club-World-Cup"},

    {"id": "2ead6347", "title": "Superclasico-River-Plate-Boca-Juniors-December-9-2018-Copa-Libertadores"},
    {"id": "78257413", "title": "Flamengo-River-Plate-November-23-2019-Copa-Libertadores"},
    {"id": "fa087c3d", "title": "Palmeiras-Santos-January-30-2021-Copa-Libertadores"},
    {"id": "8ab83903", "title": "Palmeiras-Flamengo-November-27-2021-Copa-Libertadores"},
    {"id": "4cf25a8c", "title": "Flamengo-Athletico-Paranaense-October-29-2022-Copa-Libertadores"},
    {"id": "949bd8d0", "title": "Boca-Juniors-Fluminense-November-4-2023-Copa-Libertadores"},
    {"id": "5e4ed85c", "title": "Atletico-Mineiro-Botafogo-RJ-November-30-2024-Copa-Libertadores"},
    {"id": "c504a15d", "title": "Palmeiras-Flamengo-November-29-2025-Copa-Libertadores"}
]

num_finals = len(finals_fbref)
print(f"There are {num_finals} finals in the list.")
# Out:
# There are 36 finals in the list.

# %%
headless = False  
chrome_options = Options()
if headless:
    chrome_options.add_argument("--headless")
    chrome_options.add_argument("--disable-gpu")
chrome_options.add_argument("--window-size=1280,800")
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--disable-dev-shm-usage")

service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)

# -----------------------------
# 3. Fbref Finals Scraping
# -----------------------------

results = []

try:
    for match in finals_fbref:
        match_id = match["id"]
        match_title = match["title"]
        url = f"https://fbref.com/en/matches/{match_id}/{match_title}"
        print(f"Visiting: {url}")

        driver.get(url)
        time.sleep(5)  

        html = driver.page_source

        results.append({
            "id": match_id,
            "title": match_title,
            "url": url,
            "html": html
        })

        print(f"Scraped HTML for: {match_title}")

finally:
    driver.quit()
# Out:
# Visiting: https://fbref.com/en/matches/8f71b212/Real-Madrid-Liverpool-May-26-2018-Champions-League
# Scraped HTML for: Real-Madrid-Liverpool-May-26-2018-Champions-League
# Visiting: https://fbref.com/en/matches/96de6624/Tottenham-Hotspur-Liverpool-June-1-2019-Champions-League
# Scraped HTML for: Tottenham-Hotspur-Liverpool-June-1-2019-Champions-League
# Visiting: https://fbref.com/en/matches/f3c64f12/Paris-Saint-Germain-Bayern-Munich-August-23-2020-Champions-League
# Scraped HTML for: Paris-Saint-Germain-Bayern-Munich-August-23-2020-Champions-League
# Visiting: https://fbref.com/en/matches/74010cc4/Manchester-City-Chelsea-May-29-2021-Champions-League
# Scraped HTML for: Manchester-City-Chelsea-May-29-2021-Champions-League
# Visiting: https://fbref.com/en/matches/e81453d3/Liverpool-Real-Madrid-May-28-2022-Champions-League
# Scraped HTML for: Liverpool-Real-Madrid-May-28-2022-Champions-League
# Visiting: https://fbref.com/en/matches/32081d2b/Manchester-City-Internazionale-June-10-2023-Champions-League
# Scraped HTML for: Manchester-City-Internazionale-June-10-2023-Champions-League
# Visiting: https://fbref.com/en/matches/92843563/Dortmund-Real-Madrid-June-1-2024-Champions-League
# Scraped HTML for: Dortmund-Real-Madrid-June-1-2024-Champions-League
# Visiting: https://fbref.com/en/matches/5185c7d5/Paris-Saint-Germain-Internazionale-May-31-2025-Champions-League
# Scraped HTML for: Paris-Saint-Germain-Internazionale-May-31-2025-Champions-League
# Visiting: https://fbref.com/en/matches/799cf803/Nigeria-Cote-dIvoire-February-11-2024-Africa-Cup-of-Nations
# Scraped HTML for: Nigeria-Cote-dIvoire-February-11-2024-Africa-Cup-of-Nations
# Visiting: https://fbref.com/en/matches/2ca5b81c/Senegal-Egypt-February-6-2022-Africa-Cup-of-Nations
# Scraped HTML for: Senegal-Egypt-February-6-2022-Africa-Cup-of-Nations
# Visiting: https://fbref.com/en/matches/deaede2a/Senegal-Algeria-July-19-2019-Africa-Cup-of-Nations
# Scraped HTML for: Senegal-Algeria-July-19-2019-Africa-Cup-of-Nations
# Visiting: https://fbref.com/en/matches/39b037a9/Argentina-Colombia-July-14-2024-Copa-America
# Scraped HTML for: Argentina-Colombia-July-14-2024-Copa-America
# Visiting: https://fbref.com/en/matches/1309eaf0/Argentina-Brazil-July-10-2021-Copa-America
# Scraped HTML for: Argentina-Brazil-July-10-2021-Copa-America
# Visiting: https://fbref.com/en/matches/33ec99f1/Brazil-Peru-July-7-2019-Copa-America
# Scraped HTML for: Brazil-Peru-July-7-2019-Copa-America
# Visiting: https://fbref.com/en/matches/e307ecc0/Spain-England-July-14-2024-UEFA-Euro-2024
# Scraped HTML for: Spain-England-July-14-2024-UEFA-Euro-2024
# Visiting: https://fbref.com/en/matches/56228480/Italy-England-July-11-2021-UEFA-Euro-2020
# Scraped HTML for: Italy-England-July-11-2021-UEFA-Euro-2020
# Visiting: https://fbref.com/en/matches/dc399ca6/Portugal-Spain-June-8-2025-UEFA-Nations-League
# Scraped HTML for: Portugal-Spain-June-8-2025-UEFA-Nations-League
# Visiting: https://fbref.com/en/matches/c7cc0ff5/Croatia-Spain-June-18-2023-UEFA-Nations-League
# Scraped HTML for: Croatia-Spain-June-18-2023-UEFA-Nations-League
# Visiting: https://fbref.com/en/matches/82df6636/Spain-France-October-10-2021-UEFA-Nations-League
# Scraped HTML for: Spain-France-October-10-2021-UEFA-Nations-League
# Visiting: https://fbref.com/en/matches/322368d7/Portugal-Netherlands-June-9-2019-UEFA-Nations-League
# Scraped HTML for: Portugal-Netherlands-June-9-2019-UEFA-Nations-League
# Visiting: https://fbref.com/en/matches/6d9230c5/Jordan-Qatar-February-10-2024-Asian-Cup
# Scraped HTML for: Jordan-Qatar-February-10-2024-Asian-Cup
# Visiting: https://fbref.com/en/matches/a7940000/Japan-Qatar-February-1-2019-Asian-Cup
# Scraped HTML for: Japan-Qatar-February-1-2019-Asian-Cup
# Visiting: https://fbref.com/en/matches/ed5dc867/Chelsea-Paris-Saint-Germain-July-13-2025-FIFA-Club-World-Cup
# Scraped HTML for: Chelsea-Paris-Saint-Germain-July-13-2025-FIFA-Club-World-Cup
# Visiting: https://fbref.com/en/matches/790561d3/Manchester-City-Fluminense-December-22-2023-FIFA-Club-World-Cup
# Scraped HTML for: Manchester-City-Fluminense-December-22-2023-FIFA-Club-World-Cup
# Visiting: https://fbref.com/en/matches/b96f7ccb/Real-Madrid-Al-Hilal-February-11-2023-FIFA-Club-World-Cup
# Scraped HTML for: Real-Madrid-Al-Hilal-February-11-2023-FIFA-Club-World-Cup
# Visiting: https://fbref.com/en/matches/1d346ab2/Chelsea-Palmeiras-February-12-2022-FIFA-Club-World-Cup
# Scraped HTML for: Chelsea-Palmeiras-February-12-2022-FIFA-Club-World-Cup
# Visiting: https://fbref.com/en/matches/abd98ebb/Bayern-Munich-UANL-February-11-2021-FIFA-Club-World-Cup
# Scraped HTML for: Bayern-Munich-UANL-February-11-2021-FIFA-Club-World-Cup
# Visiting: https://fbref.com/en/matches/cb8fcb6b/Liverpool-Flamengo-December-21-2019-FIFA-Club-World-Cup
# Scraped HTML for: Liverpool-Flamengo-December-21-2019-FIFA-Club-World-Cup
# Visiting: https://fbref.com/en/matches/2ead6347/Superclasico-River-Plate-Boca-Juniors-December-9-2018-Copa-Libertadores
# Scraped HTML for: Superclasico-River-Plate-Boca-Juniors-December-9-2018-Copa-Libertadores
# Visiting: https://fbref.com/en/matches/78257413/Flamengo-River-Plate-November-23-2019-Copa-Libertadores
# Scraped HTML for: Flamengo-River-Plate-November-23-2019-Copa-Libertadores
# Visiting: https://fbref.com/en/matches/fa087c3d/Palmeiras-Santos-January-30-2021-Copa-Libertadores
# Scraped HTML for: Palmeiras-Santos-January-30-2021-Copa-Libertadores
# Visiting: https://fbref.com/en/matches/8ab83903/Palmeiras-Flamengo-November-27-2021-Copa-Libertadores
# Scraped HTML for: Palmeiras-Flamengo-November-27-2021-Copa-Libertadores
# Visiting: https://fbref.com/en/matches/4cf25a8c/Flamengo-Athletico-Paranaense-October-29-2022-Copa-Libertadores
# Scraped HTML for: Flamengo-Athletico-Paranaense-October-29-2022-Copa-Libertadores
# Visiting: https://fbref.com/en/matches/949bd8d0/Boca-Juniors-Fluminense-November-4-2023-Copa-Libertadores
# Scraped HTML for: Boca-Juniors-Fluminense-November-4-2023-Copa-Libertadores
# Visiting: https://fbref.com/en/matches/5e4ed85c/Atletico-Mineiro-Botafogo-RJ-November-30-2024-Copa-Libertadores
# Scraped HTML for: Atletico-Mineiro-Botafogo-RJ-November-30-2024-Copa-Libertadores
# Visiting: https://fbref.com/en/matches/c504a15d/Palmeiras-Flamengo-November-29-2025-Copa-Libertadores
# Scraped HTML for: Palmeiras-Flamengo-November-29-2025-Copa-Libertadores

# %%
# Export results to CSV
import csv
csv_file = "fbref_matches_full_html.csv"
with open(csv_file, "w", newline="", encoding="utf-8") as f:
    fieldnames = ["id", "title", "url", "html"]
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    for row in results:
        writer.writerow(row)

print(f"Scraping complete. Data saved to {csv_file}")
# Out:
# Scraping complete. Data saved to fbref_matches_full_html.csv

# %%
# Load and display the saved CSV file
import pandas as pd

csv_file = "fbref_matches_full_html.csv"
data = pd.read_csv(csv_file)

print(data.head())
# Out:
#          id                                              title  \
# 0  8f71b212  Real-Madrid-Liverpool-May-26-2018-Champions-Le...
# 1  96de6624  Tottenham-Hotspur-Liverpool-June-1-2019-Champi...
# 2  f3c64f12  Paris-Saint-Germain-Bayern-Munich-August-23-20...
# 3  74010cc4  Manchester-City-Chelsea-May-29-2021-Champions-...
# 4  e81453d3  Liverpool-Real-Madrid-May-28-2022-Champions-Le...
#
#                                                  url  \
# 0  https://fbref.com/en/matches/8f71b212/Real-Mad...
# 1  https://fbref.com/en/matches/96de6624/Tottenha...
# 2  https://fbref.com/en/matches/f3c64f12/Paris-Sa...
# 3  https://fbref.com/en/matches/74010cc4/Manchest...
# 4  https://fbref.com/en/matches/e81453d3/Liverpoo...
#
#                                                 html
# 0  <html data-version="klecko-" data-root="/home/...
# 1  <html data-version="klecko-" data-root="/home/...
# 2  <html data-version="klecko-" data-root="/home/...
# 3  <html data-version="klecko-" data-root="/home/...
# 4  <html data-version="klecko-" data-root="/home/...

# %%
# Out:
# There are 36 matches in the list.
